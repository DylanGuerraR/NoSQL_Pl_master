# %% [markdown]
# # Consultas contra la base de datos local "ucm_nosql_pl"

# %% [markdown]
# ## a.El Total de locales y terrazas por distrito y barrio: construye una consulta que permita obtener el total de locales y terrazas agrupados por cada distrito y barrio.

# %%
#------------Dependencies-----------#
import pandas as pd
import pymongo as mongo

# %%
def mostrar_resultado(result, n=5):
    """
    Convierte un cursor de MongoDB a DataFrame y muestra las primeras filas.

    Parámetros:
    - result: cursor devuelto por find() o aggregate()
    - n: número de filas a mostrar (por defecto 5)
    """
    df_resultado = pd.DataFrame(list(result))
    return df_resultado.head(n)

# %%
# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = mongo.MongoClient('mongodb://localhost:27017/')
result = client['ucm_nosql_pl']['locales'].aggregate([
    {
        '$lookup': {
            'from': 'terrazas',
            'localField': 'id_local',
            'foreignField': 'id_local',
            'as': 'terrazas_asociadas'
        }
    }, {
        '$group': {
            '_id': {
                'distrito': '$desc_distrito_local',
                'barrio': '$desc_barrio_local'
            },
            'total_locales': {
                '$sum': 1
            },
            'locales_con_terraza': {
                '$sum': {
                    '$cond': [
                        {
                            '$gt': [
                                {
                                    '$size': '$terrazas_asociadas'
                                }, 0
                            ]
                        }, 1, 0
                    ]
                }
            }
        }
    }
])

mostrar_resultado(result,5)
# Out:
#                                                  _id  total_locales  \
# 0  {'distrito': 'moncloa-aravaca', 'barrio': 'ciu...            898
# 1  {'distrito': 'villa de vallecas', 'barrio': 'c...           3667
# 2  {'distrito': 'ciudad lineal', 'barrio': 'ventas'}           2790
# 3   {'distrito': 'moratalaz', 'barrio': 'fontarron'}            376
# 4    {'distrito': 'arganzuela', 'barrio': 'legazpi'}            508
#
#    locales_con_terraza
# 0                   22
# 1                   64
# 2                   54
# 3                   17
# 4                   49

# %% [markdown]
# ## b.Tipos de licencias y cantidad de licencias por cada tipo: crea una consulta para contar cuántas licencias hay de cada tipo en los datos.

# %%
from pymongo import MongoClient

# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb://localhost:27017/')
result = client['ucm_nosql_pl']['licencias'].aggregate([
    {
        '$group': {
            '_id': {
                'id_tipo_licencia': '$id_tipo_licencia'
            },
            'total_licencias_x_tipo': {
                '$sum': 1
            }
        }
    }
])
mostrar_resultado(result,5)
# Out:
#                        _id  total_licencias_x_tipo
# 0  {'id_tipo_licencia': 4}                   57028
# 1  {'id_tipo_licencia': 0}                    5956
# 2  {'id_tipo_licencia': 3}                    5813
# 3  {'id_tipo_licencia': 1}                   51249
# 4  {'id_tipo_licencia': 2}                   30783

# %% [markdown]
# ## c.Listado de locales y terrazas con licencias “En trámite”: diseña una consulta que filtre y devuelva un listado detallado de locales y terrazas cuyo estado de licencia sea “En trámite”.

# %%
 # Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb://localhost:27017/')
result = client['ucm_nosql_pl']['locales'].aggregate([
    {
        '$lookup': {
            'from': 'terrazas',
            'localField': 'id_local',
            'foreignField': 'id_local',
            'as': 'terrazas_asociadas'
        }
    }, {
        '$lookup': {
            'from': 'licencias',
            'localField': 'id_local',
            'foreignField': 'id_local',
            'as': 'licencias_x_local'
        }
    }, {
        '$match': {
            'licencias_x_local.desc_tipo_situacion_licencia': 'en tramitación'
        }
    }, {
        '$project': {
            'id_local': 1,
            'desc_distrito_local': 1,
            'desc_barrio_local': 1,
            'licencias_en_tramite': {
                '$filter': {
                    'input': '$licencias_x_local',
                    'as': 'lic',
                    'cond': {
                        '$eq': [
                            '$$lic.desc_tipo_situacion_licencia', 'en tramitación'
                        ]
                    }
                }
            }
        }
    }
])
mostrar_resultado(result,5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 43
#       4 client = MongoClient('mongodb://localhost:27017/')
#       5 result = client['ucm_nosql_pl']['locales'].aggregate([
#       6     {
#       7         '$lookup': {
#    (...)     41     }
#      42 ])
# ---> 43 mostrar_resultado(result,5)
#
# Cell In[9], line 9, in mostrar_resultado(result, n)
#       1 def mostrar_resultado(result, n=5):
#       2     """
#       3     Convierte un cursor de MongoDB a DataFrame y muestra las primeras filas.
#       4
#    (...)      7     - n: número de filas a mostrar (por defecto 5)
#       8     """
# ----> 9     df_resultado = pd.DataFrame(list(result))
#      10     return df_resultado.head(n)
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\command_cursor.py:342, in CommandCursor.__next__(self)
#     341 def __next__(self) -> _DocumentType:
# --> 342     return self.next()
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\command_cursor.py:335, in CommandCursor.next(self)
#     333 # Block until a document is returnable.
#     334 while self.alive:
# --> 335     doc = self._try_next(True)
#     336     if doc is not None:
#     337         return doc
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\command_cursor.py:347, in CommandCursor._try_next(self, get_more_allowed)
#     345 """Advance the cursor blocking for at most one getMore command."""
#     346 if not len(self._data) and not self._killed and get_more_allowed:
# --> 347     self._refresh()
#     348 if len(self._data):
#     349     return self._data.popleft()
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\command_cursor.py:307, in CommandCursor._refresh(self)
#     305     dbname, collname = self._ns.split(".", 1)
#     306     read_pref = self._collection._read_preference_for(self.session)
# --> 307     self._send_message(
#     308         self._getmore_class(
#     309             dbname,
#     310             collname,
#     311             self._batch_size,
#     312             self._id,
#     313             self._collection.codec_options,
#     314             read_pref,
#     315             self._session,
#     316             self._collection.database.client,
#     317             self._max_await_time_ms,
#     318             self._sock_mgr,
#     319             False,
#     320             self._comment,
#     321         )
#     322     )
#     323 else:  # Cursor id is zero nothing else to return
#     324     self._die_lock()
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\command_cursor.py:254, in CommandCursor._send_message(self, operation)
#     252 client = self._collection.database.client
#     253 try:
# --> 254     response = client._run_operation(
#     255         operation, self._unpack_response, address=self._address
#     256     )
#     257 except OperationFailure as exc:
#     258     if exc.code in _CURSOR_CLOSED_ERRORS:
#     259         # Don't send killCursors because the cursor is already closed.
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\mongo_client.py:1917, in MongoClient._run_operation(self, operation, unpack_res, address)
#    1907     operation.reset()  # Reset op in case of retry.
#    1908     return server.run_operation(
#    1909         conn,
#    1910         operation,
#    (...)   1914         self,
#    1915     )
# -> 1917 return self._retryable_read(
#    1918     _cmd,
#    1919     operation.read_preference,
#    1920     operation.session,  # type: ignore[arg-type]
#    1921     address=address,
#    1922     retryable=isinstance(operation, _Query),
#    1923     operation=operation.name,
#    1924 )
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\mongo_client.py:2026, in MongoClient._retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2021 # Ensure that the client supports retrying on reads and there is no session in
#    2022 # transaction, otherwise, we will not support retry behavior for this call.
#    2023 retryable = bool(
#    2024     retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2025 )
# -> 2026 return self._retry_internal(
#    2027     func,
#    2028     session,
#    2029     None,
#    2030     operation,
#    2031     is_read=True,
#    2032     address=address,
#    2033     read_pref=read_pref,
#    2034     retryable=retryable,
#    2035     operation_id=operation_id,
#    2036 )
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\mongo_client.py:1993, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1956 @_csot.apply
#    1957 def _retry_internal(
#    1958     self,
#    (...)   1967     operation_id: Optional[int] = None,
#    1968 ) -> T:
#    1969     """Internal retryable helper for all client transactions.
#    1970
#    1971     :param func: Callback function we want to retry
#    (...)   1980     :return: Output of the calling func()
#    1981     """
#    1982     return _ClientConnectionRetryable(
#    1983         mongo_client=self,
#    1984         func=func,
#    1985         bulk=bulk,
#    1986         operation=operation,
#    1987         is_read=is_read,
#    1988         session=session,
#    1989         read_pref=read_pref,
#    1990         address=address,
#    1991         retryable=retryable,
#    1992         operation_id=operation_id,
# -> 1993     ).run()
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\mongo_client.py:2730, in _ClientConnectionRetryable.run(self)
#    2728 self._check_last_error(check_csot=True)
#    2729 try:
# -> 2730     return self._read() if self._is_read else self._write()
#    2731 except ServerSelectionTimeoutError:
#    2732     # The application may think the write was never attempted
#    2733     # if we raise ServerSelectionTimeoutError on the retry
#    2734     # attempt. Raise the original exception instead.
#    2735     self._check_last_error()
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\mongo_client.py:2891, in _ClientConnectionRetryable._read(self)
#    2883 if self._retrying:
#    2884     _debug_log(
#    2885         _COMMAND_LOGGER,
#    2886         message=f"Retrying read attempt number {self._attempt_number}",
#    (...)   2889         operationId=self._operation_id,
#    2890     )
# -> 2891 return self._func(self._session, self._server, conn, read_pref)
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\mongo_client.py:1908, in MongoClient._run_operation.<locals>._cmd(_session, server, conn, read_preference)
#    1901 def _cmd(
#    1902     _session: Optional[ClientSession],
#    1903     server: Server,
#    1904     conn: Connection,
#    1905     read_preference: _ServerMode,
#    1906 ) -> Response:
#    1907     operation.reset()  # Reset op in case of retry.
# -> 1908     return server.run_operation(
#    1909         conn,
#    1910         operation,
#    1911         read_preference,
#    1912         self._event_listeners,
#    1913         unpack_res,
#    1914         self,
#    1915     )
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\helpers.py:47, in _handle_reauth.<locals>.inner(*args, **kwargs)
#      44 from pymongo.synchronous.pool import Connection
#      46 try:
# ---> 47     return func(*args, **kwargs)
#      48 except OperationFailure as exc:
#      49     if no_reauth:
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\server.py:208, in Server.run_operation(self, conn, operation, read_preference, listeners, unpack_res, client)
#     206 else:
#     207     conn.send_message(data, max_doc_size)
# --> 208     reply = conn.receive_message(request_id)
#     210 # Unpack and check for command errors.
#     211 if use_cmd:
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\pool.py:470, in Connection.receive_message(self, request_id)
#     468 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     469 except BaseException as error:
# --> 470     self._raise_connection_failure(error)
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\synchronous\pool.py:467, in Connection.receive_message(self, request_id)
#     462 """Receive a raw BSON message or raise ConnectionFailure.
#     463
#     464 If any exception is raised, the socket is closed.
#     465 """
#     466 try:
# --> 467     return receive_message(self, request_id, self.max_message_size)
#     468 # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#     469 except BaseException as error:
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\network_layer.py:759, in receive_message(conn, request_id, max_message_size)
#     757         deadline = None
#     758 # Ignore the response's request id.
# --> 759 length, _, response_to, op_code = _UNPACK_HEADER(receive_data(conn, 16, deadline))
#     760 # No request_id for exhaust cursor "getMore".
#     761 if request_id is not None:
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\network_layer.py:343, in receive_data(conn, length, deadline)
#     339 try:
#     340     # Use the legacy wait_for_read cancellation approach on PyPy due to PYTHON-5011.
#     341     # also use it on Windows due to PYTHON-5405
#     342     if _PYPY or _WINDOWS:
# --> 343         wait_for_read(conn, deadline)
#     344         if _csot.get_timeout() and deadline is not None:
#     345             conn.set_conn_timeout(max(deadline - time.monotonic(), 0))
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\network_layer.py:316, in wait_for_read(conn, deadline)
#     314     else:
#     315         timeout = _POLL_TIMEOUT
# --> 316     readable = conn.socket_checker.select(sock, read=True, timeout=timeout)
#     317 if conn.cancel_context.cancelled:
#     318     raise _OperationCancelled("operation cancelled")
#
# File ~\anaconda3\envs\NoSQL_Pl_master\Lib\site-packages\pymongo\socket_checker.py:77, in SocketChecker.select(self, sock, read, write, timeout)
#      75 rlist = [sock] if read else []
#      76 wlist = [sock] if write else []
# ---> 77 res = select.select(rlist, wlist, [sock], timeout)
#      78 # select returns a 3-tuple of lists of objects that are
#      79 # ready: subsets of the first three arguments. Return
#      80 # True if any of the lists are not empty.
#      81 return any(res)
#
# KeyboardInterrupt:

# %% [markdown]
# ![MongoDB_Carga_Exitosa](imagenes_capturas_mongo/query_C.png)
#
#
# **Sin indices creados, las querys pueden ser muy largas si se trata de hacer uniones por referencia**

# %% [markdown]
# ## d.Consulta por sección, división y epígrafe de la actividad comercial: crea una consulta para clasificar locales y terrazas según los campos sección, división y epígrafe.

# %%
# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb://localhost:27017/')
result = client['ucm_nosql_pl']['locales'].aggregate([
    {
        '$lookup': {
            'from': 'terrazas',
            'localField': 'id_local',
            'foreignField': 'id_local',
            'as': 'terrazas_x_locales'
        }
    }, {
        '$match': {
            'actividades.0': {
                '$exists': True
            },
            'terrazas_x_locales.0': {
                '$exists': True
            }
        }
    }, {
        '$unwind': {
            'path': '$actividades'
        }
    }, {
        '$unwind': {
            'path': '$terrazas_x_locales'
        }
    }, {
        '$match': {
            '$and': [
                {
                    'actividades.desc_seccion': {
                        '$ne': None
                    }
                }, {
                    'actividades.desc_division': {
                        '$ne': None
                    }
                }, {
                    'actividades.desc_epigrafe': {
                        '$ne': None
                    }
                }
            ]
        }
    }, {
        '$group': {
            '_id': {
                'seccion': '$actividades.desc_seccion',
                'division': '$actividades.desc_division',
                'epigrafe': '$actividades.desc_epigrafe'
            },
            'total_locales_con_terraza': {
                '$sum': 1
            }
        }
    }
])
mostrar_resultado(result,5) #MUY PESADO SIN INDICES
# Out:
#                                                  _id  \
# 0  {'seccion': 'actividades artísticas, recreativ...
# 1  {'seccion': 'educación', 'division': 'educació...
# 2  {'seccion': 'actividades artísticas, recreativ...
# 3  {'seccion': 'comercio al por mayor y al por me...
# 4  {'seccion': 'hostelería', 'division': 'servici...
#
#    total_locales_con_terraza
# 0                          2
# 1                          1
# 2                          7
# 3                          1
# 4                         33

# %% [markdown]
# ## e.Actividad económica más frecuente por barrio y distrito: diseña una consulta que identifique cuál es la actividad económica predominante en cada barrio y distrito.

# %%
# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb://localhost:27017/')
result = client['ucm_nosql_pl']['locales'].aggregate([
    {
        '$unwind': {
            'path': '$actividades'
        }
    }, {
        '$group': {
            '_id': {
                'actividad': '$actividades.desc_division',
                'distrito': '$desc_distrito_local',
                'barrio': '$desc_barrio_local'
            },
            'numero_de_actividades': {
                '$sum': 1
            }
        }
    }, {
        '$sort': {
            '_id.distrito': 1,
            '_id.barrio': 1,
            'numero_de_actividades': -1
        }
    }, {
        '$group': {
            '_id': {
                'distrito': '$_id.distrito',
                'barrio': '$_id.barrio'
            },
            'actividad_mas_frecuente': {
                '$first': '$_id.actividad'
            },
            'frecuencia': {
                '$first': '$numero_de_actividades'
            }
        }
    }
])
mostrar_resultado(result,5)
# Out:
#                                                  _id  \
# 0  {'distrito': 'carabanchel', 'barrio': 'san isi...
# 1  {'distrito': 'fuencarral-el pardo', 'barrio': ...
# 2  {'distrito': 'retiro', 'barrio': 'los jeronimos'}
# 3     {'distrito': 'arganzuela', 'barrio': 'atocha'}
# 4         {'distrito': 'centro', 'barrio': 'cortes'}
#
#                              actividad_mas_frecuente  frecuencia
# 0                               valor nulo en origen         888
# 1                               valor nulo en origen           6
# 2                     servicios de comidas y bebidas         100
# 3  comercio al por menor, excepto de vehículos de...          81
# 4                     servicios de comidas y bebidas         448

# %% [markdown]
# ## f.Actualización de horarios de apertura y cierre de ciertos locales: modifica los horarios de apertura y cierre de un conjunto seleccionado de locales según un criterio que tú determines.

# %% [markdown]
# ![MongoDB_Carga_Exitosa](imagenes_capturas_mongo/Query_ultima.png)

# %% [markdown]
# ##  Actualización de horarios de cierre en zonas turísticas
#
# Como parte del mantenimiento y mejora del modelo de datos, se ha realizado una **actualización de los horarios de cierre (`hora_cierre1` y `hora_cierre2`)** de ciertos locales ubicados en zonas históricas y turísticas de la ciudad.
#
# ###  Criterio utilizado
# Se han seleccionado los locales cuya propiedad `desc_distrito_local` corresponde a los siguientes distritos:
#
# - **Centro**
# - **Chamberí**
# - **Retiro**
#
# Estos distritos representan áreas céntricas con alta densidad de turismo, ocio nocturno y residencias, donde suelen aplicarse **normativas municipales de control del ruido y del descanso vecinal**.
#
# ###  Modificación aplicada
# Se ha actualizado el horario de cierre de estos locales a las **01:00:00** en ambos campos de hora:
#
# ```json
# {
#   "hora_cierre1": "01:00:00",
#   "hora_cierre2": "01:00:00"
# }

# %% [markdown]
# ## 3 Creación y uso de indices

# %% [markdown]
# ![MongoDB_Creacion_Indices](imagenes_capturas_mongo/creacion_indices.png)
#
# **Creación de indices**

# %% [markdown]
# ![MongoDB_Prueba_Indice](imagenes_capturas_mongo/indice_usado.png)
# **Prueba de uso de indice**

# %% [markdown]
# ## Plan de ejecución de las consultas y diferencia de tiempos

# %% [markdown]
# ## a.El Total de locales y terrazas por distrito y barrio: construye una consulta que permita obtener el total de locales y terrazas agrupados por cada distrito y barrio.

# %%
# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = mongo.MongoClient('mongodb://localhost:27017/')
result = client['ucm_nosql_pl']['locales'].aggregate([
    {
        '$lookup': {
            'from': 'terrazas',
            'localField': 'id_local',
            'foreignField': 'id_local',
            'as': 'terrazas_asociadas'
        }
    }, {
        '$group': {
            '_id': {
                'distrito': '$desc_distrito_local',
                'barrio': '$desc_barrio_local'
            },
            'total_locales': {
                '$sum': 1
            },
            'locales_con_terraza': {
                '$sum': {
                    '$cond': [
                        {
                            '$gt': [
                                {
                                    '$size': '$terrazas_asociadas'
                                }, 0
                            ]
                        }, 1, 0
                    ]
                }
            }
        }
    }
])

mostrar_resultado(result,5)
# Out:
#                                                  _id  total_locales  \
# 0     {'distrito': 'usera', 'barrio': 'almendrales'}           1058
# 1        {'distrito': 'usera', 'barrio': 'moscardo'}           1492
# 2    {'distrito': 'chamartin', 'barrio': 'castilla'}            756
# 3  {'distrito': 'moncloa-aravaca', 'barrio': 'val...            101
# 4    {'distrito': 'hortaleza', 'barrio': 'canillas'}           1964
#
#    locales_con_terraza
# 0                   19
# 1                   40
# 2                   43
# 3                    2
# 4                   61

# %% [markdown]
# ## b.Tipos de licencias y cantidad de licencias por cada tipo: crea una consulta para contar cuántas licencias hay de cada tipo en los datos.

# %%
from pymongo import MongoClient

# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb://localhost:27017/')
result = client['ucm_nosql_pl']['licencias'].aggregate([
    {
        '$group': {
            '_id': {
                'id_tipo_licencia': '$id_tipo_licencia'
            },
            'total_licencias_x_tipo': {
                '$sum': 1
            }
        }
    }
])
mostrar_resultado(result,5)
# Out:
#                        _id  total_licencias_x_tipo
# 0  {'id_tipo_licencia': 3}                    5813
# 1  {'id_tipo_licencia': 1}                   51249
# 2  {'id_tipo_licencia': 2}                   30783
# 3  {'id_tipo_licencia': 4}                   57028
# 4  {'id_tipo_licencia': 0}                    5956

# %% [markdown]
# ## c.Listado de locales y terrazas con licencias “En trámite”: diseña una consulta que filtre y devuelva un listado detallado de locales y terrazas cuyo estado de licencia sea “En trámite”.

# %% [markdown]
# ## Creación de indices para mejorar el tiempo de respuesta de esta query que antes pasó mas de 5 minutos y no devolvía respuesta

# %% [markdown]
# ![MongoDB_Prueba_Indice](imagenes_capturas_mongo/indice_usado.png)

# %%
 # Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb://localhost:27017/')
result = client['ucm_nosql_pl']['locales'].aggregate([
    {
        '$lookup': {
            'from': 'terrazas',
            'localField': 'id_local',
            'foreignField': 'id_local',
            'as': 'terrazas_asociadas'
        }
    }, {
        '$lookup': {
            'from': 'licencias',
            'localField': 'id_local',
            'foreignField': 'id_local',
            'as': 'licencias_x_local'
        }
    }, {
        '$match': {
            'licencias_x_local.desc_tipo_situacion_licencia': 'en tramitación'
        }
    }, {
        '$project': {
            'id_local': 1,
            'desc_distrito_local': 1,
            'desc_barrio_local': 1,
            'licencias_en_tramite': {
                '$filter': {
                    'input': '$licencias_x_local',
                    'as': 'lic',
                    'cond': {
                        '$eq': [
                            '$$lic.desc_tipo_situacion_licencia', 'en tramitación'
                        ]
                    }
                }
            }
        }
    }
])
mostrar_resultado(result,5)
# Out:
#                         _id  id_local desc_distrito_local  \
# 0  685a81586586723066b49382  20000596          arganzuela
# 1  685a81586586723066b49385  20000709          arganzuela
# 2  685a81586586723066b49387  20000729          arganzuela
# 3  685a81586586723066b49388  20000756          arganzuela
# 4  685a81586586723066b4938a  20000764          arganzuela
#
#       desc_barrio_local                               licencias_en_tramite
# 0               chopera  [{'_id': 685a815d6586723066b87c64, 'id_local':...
# 1               acacias  [{'_id': 685a815d6586723066b88458, 'id_local':...
# 2              delicias  [{'_id': 685a815d6586723066b87da0, 'id_local':...
# 3  palos de la frontera  [{'_id': 685a815d6586723066b881bf, 'id_local':...
# 4               acacias  [{'_id': 685a815d6586723066b88492, 'id_local':...

# %% [markdown]
# ## HA TARDADO SOLO 3 S 592 MS IMPRESIONANTE¡

# %% [markdown]
# ## d.Consulta por sección, división y epígrafe de la actividad comercial: crea una consulta para clasificar locales y terrazas según los campos sección, división y epígrafe.

# %%
# Requires the PyMongo package.
# https://api.mongodb.com/python/current

client = MongoClient('mongodb://localhost:27017/')
result = client['ucm_nosql_pl']['locales'].aggregate([
    {
        '$unwind': {
            'path': '$actividades'
        }
    }, {
        '$group': {
            '_id': {
                'actividad': '$actividades.desc_division',
                'distrito': '$desc_distrito_local',
                'barrio': '$desc_barrio_local'
            },
            'numero_de_actividades': {
                '$sum': 1
            }
        }
    }, {
        '$sort': {
            '_id.distrito': 1,
            '_id.barrio': 1,
            'numero_de_actividades': -1
        }
    }, {
        '$group': {
            '_id': {
                'distrito': '$_id.distrito',
                'barrio': '$_id.barrio'
            },
            'actividad_mas_frecuente': {
                '$first': '$_id.actividad'
            },
            'frecuencia': {
                '$first': '$numero_de_actividades'
            }
        }
    }
])
mostrar_resultado(result,5)
# Out:
#                                                  _id actividad_mas_frecuente  \
# 0  {'distrito': 'ciudad lineal', 'barrio': 'colina'}    valor nulo en origen
# 1  {'distrito': 'puente de vallecas', 'barrio': '...    valor nulo en origen
# 2     {'distrito': 'latina', 'barrio': 'campamento'}    valor nulo en origen
# 3    {'distrito': 'chamartin', 'barrio': 'castilla'}    valor nulo en origen
# 4    {'distrito': 'hortaleza', 'barrio': 'canillas'}    valor nulo en origen
#
#    frecuencia
# 0          80
# 1         675
# 2         283
# 3         210
# 4         632
